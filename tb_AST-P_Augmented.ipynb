# %%
"""
@inproceedings{gong21b_interspeech,
  author={Yuan Gong and Yu-An Chung and James Glass},
  title={{AST: Audio Spectrogram Transformer}},
  year=2021,
  booktitle={Proc. Interspeech 2021},
  pages={571--575},
  doi={10.21437/Interspeech.2021-698}
}
"""
# Out:
# '\n@inproceedings{gong21b_interspeech,\n  author={Yuan Gong and Yu-An Chung and James Glass},\n  title={{AST: Audio Spectrogram Transformer}},\n  year=2021,\n  booktitle={Proc. Interspeech 2021},\n  pages={571--575},\n  doi={10.21437/Interspeech.2021-698}\n}\n'

# %% [markdown]
# ### Library Imports & Environment Setup

# %%
import sys
import os
import json
import random
import argparse
import numpy as np
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
from collections import defaultdict
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    roc_auc_score, average_precision_score,
    roc_curve, confusion_matrix, ConfusionMatrixDisplay
)

# ── Path setup ────────────────────────────────────────────────────────────────
sys.path.append('./src')
os.environ['TORCH_HOME'] = '../pretrained_models'

from models import ASTModel
import dataloader
from traintest import train, validate

# ── Reproducibility ───────────────────────────────────────────────────────────
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device : {device}")
print(f"PyTorch      : {torch.__version__}")
print(f"Seed         : {SEED}")
# Out:
# Using device : cpu
# PyTorch      : 1.8.1+cpu
# Seed         : 42

# %% [markdown]
# ### Patient-Level Stratified Split

# %%
def prepare_ast_patient_split(
    root_path: str,
    val_ratio: float = 0.15,
    test_ratio: float = 0.15,
    seed: int = 42,
    save_dir: str = "."
):
    FOLDER_LABEL = {
        "Cough_PTB":     "1",   # PTB   → class index 1
        "Cough_Non-PTB": "0",   # Non-PTB → class index 0
    }
    LABEL_NAME = {"1": "PTB", "0": "Non-PTB"}

    # ── 1. สแกนและจัดกลุ่มตาม Patient ID ────────────────────────────────────
    # patient_info: {patient_id: {"label": "0"/"1", "files": [path, ...]} }
    patient_info = {}

    for folder_name, label_str in FOLDER_LABEL.items():
        folder_path = os.path.join(root_path, folder_name)
        if not os.path.exists(folder_path):
            print(f"[WARN] โฟลเดอร์ไม่พบ: {folder_path}")
            continue

        for file in sorted(os.listdir(folder_path)):
            if not file.lower().endswith(".wav"):
                continue
            patient_id = file.split("_")[0]          # เช่น "006", "008", "001"
            full_path  = os.path.abspath(os.path.join(folder_path, file))

            if patient_id not in patient_info:
                patient_info[patient_id] = {"label": label_str, "files": []}
            patient_info[patient_id]["files"].append(full_path)

    # ── 2. แยก Patient ID และ Class Label เพื่อใช้กับ stratify ──────────────
    patient_ids    = list(patient_info.keys())
    patient_labels = [patient_info[pid]["label"] for pid in patient_ids]   # "0" / "1"

    # ── 3. Stratified Split ───────────────────────────────────────────────────
    # temp_ratio = val + test  (หักจากทั้งหมด)
    temp_ratio = val_ratio + test_ratio   # e.g. 0.30

    train_ids, temp_ids, train_labels, temp_labels = train_test_split(
        patient_ids, patient_labels,
        test_size=temp_ratio,
        stratify=patient_labels,
        random_state=seed
    )

    # แบ่ง temp → val / test  (test_ratio / temp_ratio = proportion within temp)
    relative_test_ratio = test_ratio / temp_ratio   # e.g. 0.15 / 0.30 = 0.50

    val_ids, test_ids, _, _ = train_test_split(
        temp_ids, temp_labels,
        test_size=relative_test_ratio,
        stratify=temp_labels,
        random_state=seed
    )

    split_map = {
        "TRAIN": set(train_ids),
        "VAL":   set(val_ids),
        "TEST":  set(test_ids),
    }

    # ── 4. สร้าง Data List และบันทึก JSON ────────────────────────────────────
    json_filename = {
        "TRAIN": os.path.join(save_dir, "train_data.json"),
        "VAL":   os.path.join(save_dir, "val_data.json"),
        "TEST":  os.path.join(save_dir, "test_data.json"),
    }

    data_lists = {"TRAIN": [], "VAL": [], "TEST": []}

    for pid, info in patient_info.items():
        for split_name, id_set in split_map.items():
            if pid in id_set:
                for path in info["files"]:
                    data_lists[split_name].append(
                        {"wav": path, "labels": info["label"]}
                    )
                break

    for split_name, data_list in data_lists.items():
        with open(json_filename[split_name], "w") as f:
            json.dump({"data": data_list}, f, indent=4)

    # ── 5. แสดงผลสรุป ─────────────────────────────────────────────────────────
    def _count_files(id_set, label):
        return sum(
            len(patient_info[pid]["files"])
            for pid in id_set
            if patient_info[pid]["label"] == label
        )

    print("=" * 60)
    print("          AST DATASET PREPARATION SUMMARY")
    print("=" * 60)
    print(f"{'Data Split':<8}  {'Patients':>8}  {'PTB (1)':>8}  {'Non-PTB (0)':>12}  {'Total':>7}")
    print("-" * 60)

    total_ptb = total_non = total_pat = 0
    for split_name, id_set in split_map.items():
        n_ptb = _count_files(id_set, "1")
        n_non = _count_files(id_set, "0")
        n_pat = len(id_set)
        total_ptb += n_ptb
        total_non += n_non
        total_pat += n_pat
        print(f"{split_name:<8}  {n_pat:>8}  {n_ptb:>8}  {n_non:>12}  {n_ptb+n_non:>7}")

    print("-" * 60)
    print(f"{'TOTAL':<8}  {total_pat:>8}  {total_ptb:>8}  {total_non:>12}  {total_ptb+total_non:>7}")
    print("=" * 60)

    for split_name, id_set in split_map.items():
        sorted_ids = sorted(id_set)
        print(f"\n{split_name} Patients ({len(sorted_ids)} คน):")

        # แสดงรายละเอียดแยกตามคลาส
        ptb_patients     = [pid for pid in sorted_ids if patient_info[pid]["label"] == "1"]
        non_ptb_patients = [pid for pid in sorted_ids if patient_info[pid]["label"] == "0"]

        if ptb_patients:
            print(f"  PTB     : {', '.join(ptb_patients)}")
            for pid in ptb_patients:
                n = len(patient_info[pid]["files"])
                print(f"             └─ {pid}  →  {n} ไฟล์")

        if non_ptb_patients:
            print(f"  Non-PTB : {', '.join(non_ptb_patients)}")
            for pid in non_ptb_patients:
                n = len(patient_info[pid]["files"])
                print(f"             └─ {pid}  →  {n} ไฟล์")

    print(f"\nบันทึกไฟล์ JSON เรียบร้อย:")
    for split_name, path in json_filename.items():
        print(f"  {split_name:<6} → {path}")

    return json_filename  # คืนพาธ JSON ไปใช้ใน Cell ถัดไป


# ── เรียกใช้งาน ───────────────────────────────────────────────────────────────
JSON_PATHS = prepare_ast_patient_split(
    root_path = "./Data",
    val_ratio  = 0.15,
    test_ratio = 0.15,
    seed       = SEED,
    save_dir   = "."
)
# Out:
# ============================================================
#           AST DATASET PREPARATION SUMMARY
# ============================================================
# Data Split  Patients   PTB (1)   Non-PTB (0)    Total
# ------------------------------------------------------------
# TRAIN           10       114           212      326
# VAL              2        42            40       82
# TEST             3        31            73      104
# ------------------------------------------------------------
# TOTAL           15       187           325      512
# ============================================================
#
# TRAIN Patients (10 คน):
#   PTB     : 006, 009, 011, 012, 015
#              └─ 006  →  52 ไฟล์
#              └─ 009  →  4 ไฟล์
#              └─ 011  →  1 ไฟล์
#              └─ 012  →  20 ไฟล์
#              └─ 015  →  37 ไฟล์
#   Non-PTB : 001, 002, 003, 007, 014
#              └─ 001  →  40 ไฟล์
#              └─ 002  →  109 ไฟล์
#              └─ 003  →  2 ไฟล์
#              └─ 007  →  11 ไฟล์
#              └─ 014  →  50 ไฟล์
#
# VAL Patients (2 คน):
#   PTB     : 008
#              └─ 008  →  42 ไฟล์
#   Non-PTB : 013
#              └─ 013  →  40 ไฟล์
#
# TEST Patients (3 คน):
#   PTB     : 016
#              └─ 016  →  31 ไฟล์
#   Non-PTB : 004, 005
#              └─ 004  →  41 ไฟล์
#              └─ 005  →  32 ไฟล์
#
# บันทึกไฟล์ JSON เรียบร้อย:
#   TRAIN  → .\train_data.json
#   VAL    → .\val_data.json
#   TEST   → .\test_data.json

# %% [markdown]
# ### Model Training — AST-P (AudioSet Pretrained)
#
# - **Model:** `ASTModel` with `audioset_pretrain=True, imagenet_pretrain=True`
# - **Resampling:** ไฟล์เสียงทุกไฟล์จะถูก Resample เป็น **16 kHz** ก่อนคำนวณ Filterbank (`src/dataloader.py`)
# - **Normalization:** AudioSet statistics — Mean = **−4.27**, Std = **4.57** (Gong et al., 2021)
# - **Loss:** Cross-Entropy (Binary, 2-class)
# - **Metrics:** mAUC (ใช้เลือก Best Epoch จาก `result.csv` col-index 1)
# - ผลการ Training จะถูกบันทึกที่ `exp/tb_ast_p_single_run/`

# %%
# ── Hyperparameters ───────────────────────────────────────────────────────────
EXP_DIR    = "./exp/tb_ast_p_augmented"
N_CLASS    = 2
BATCH_SIZE = 8
N_EPOCHS   = 20

# AudioSet Normalization Statistics
# อ้างอิง: Gong et al. (2021) — "AST: Audio Spectrogram Transformer"
# https://arxiv.org/abs/2104.01778
# Mean = -4.2677393, Std = 4.5689974  (คำนวณจาก AudioSet ทั้ง 2M คลิป)
NORM_MEAN = -4.527155
NORM_STD  =  5.118366

# ── Audio Configuration ───────────────────────────────────────────────────────
# Ref: target_length=100 → ~1 วินาที (frame_shift=10ms → 100 frames ≈ 1s)
TRAIN_AUDIO_CONF = {
    "num_mel_bins": 128,
    "target_length": 100,
    "freqm":        48,
    "timem":        20,
    "mixup":        0.5,
    "dataset":      "audioset",
    "mode":         "train",
    "mean":        NORM_MEAN,
    "std":          NORM_STD,
    "noise":        False,
    'skip_norm': False
}

EVAL_AUDIO_CONF = {
    "num_mel_bins": 128,
    "target_length": 100,
    "freqm":        0,
    "timem":        0,
    "mixup":        0.0,
    "dataset":      "audioset",
    "mode":         "evaluation",
    "mean":        NORM_MEAN,
    "std":          NORM_STD,
    "noise":        False,
    'skip_norm': False
}

os.makedirs(f"{EXP_DIR}/models", exist_ok=True)
os.makedirs(f"{EXP_DIR}/plots", exist_ok=True)
import shutil
_pred_dir = f"{EXP_DIR}/predictions"
if os.path.exists(_pred_dir):
    shutil.rmtree(_pred_dir)
    print(f"[Cleanup] Removed stale predictions folder: {_pred_dir}")

# ── DataLoaders ───────────────────────────────────────────────────────────────
train_loader = torch.utils.data.DataLoader(
    dataloader.AudiosetDataset(
        JSON_PATHS["TRAIN"],
        label_csv="class_labels_indices.csv",
        audio_conf=TRAIN_AUDIO_CONF,
    ),
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=0,
    pin_memory=True,
)

val_loader = torch.utils.data.DataLoader(
    dataloader.AudiosetDataset(
        JSON_PATHS["VAL"],
        label_csv="class_labels_indices.csv",
        audio_conf=EVAL_AUDIO_CONF,
    ),
    batch_size=BATCH_SIZE * 2,
    shuffle=False,
    num_workers=0,
    pin_memory=True,
)

print(f"Train samples : {len(train_loader.dataset)}")
print(f"Val   samples : {len(val_loader.dataset)}")

# ── AST-P Model ───────────────────────────────────────────────────────────────
# audioset_pretrain=True  →  โหลด Weights ที่ Pre-train บน AudioSet (527 คลาส)
#                            แล้ว Resize Head เป็น N_CLASS=2
ast_model = ASTModel(
    label_dim        = N_CLASS,
    fstride          = 10,
    tstride          = 10,
    input_fdim       = 128,
    input_tdim       = 100,
    imagenet_pretrain = True,
    audioset_pretrain = True,   # ← AST-P
    model_size       = "base384",
)

# ── Training Arguments ────────────────────────────────────────────────────────
args = argparse.Namespace(
    exp_dir           = EXP_DIR,
    dataset           = "audioset",
    n_class           = N_CLASS,
    lr                = 1e-5,
    n_epochs          = N_EPOCHS,
    batch_size        = BATCH_SIZE,
    n_print_steps     = 10,
    save_model        = True,
    loss              = "CE",
    metrics           = "mAP",           # ← ใช้ mAP/mAUC เป็น main metric
    lrscheduler_start = 5,
    lrscheduler_step  = 1,
    lrscheduler_decay = 0.85,
    warmup            = False,
    wa                = True,             # Weighted Averaging
    wa_start          = 10,              # เริ่มใช้ WA หลังจาก Epoch 10
    wa_end            = N_EPOCHS,
)

# ── Start Training ────────────────────────────────────────────────────────────
print(f"\nStarting AST-P Training  ({N_EPOCHS} epochs) ...")
train(ast_model, train_loader, val_loader, args)
print("\nTraining complete. Model checkpoints saved to:", EXP_DIR)
# Out:
# ---------------the train dataloader---------------
# now using following mask: 48 freq, 20 time
# now using mix-up with rate 0.500000
# now process audioset
# use dataset mean -4.527 and std 5.118 to normalize the input.
# number of classes is 2
# ---------------the evaluation dataloader---------------
# now using following mask: 0 freq, 0 time
# now using mix-up with rate 0.000000
# now process audioset
# use dataset mean -4.527 and std 5.118 to normalize the input.
# number of classes is 2
# Train samples : 326
# Val   samples : 82
# ---------------AST Model Summary---------------
# ImageNet pretraining: True, AudioSet pretraining: True
# frequncey stride=10, time stride=10
# number of patches=108
#
# Starting AST-P Training  (20 epochs) ...
# running on cpu
# Total parameter number is : 86.880 million
# Total trainable parameter number is : 86.880 million
# now training with audioset, main metrics: mAP, loss function: CrossEntropyLoss(), learning rate scheduler: <torch.optim.lr_scheduler.MultiStepLR object at 0x000001C6B6B05CA0>
# The learning rate scheduler starts at 5 epoch with decay rate of 0.850 every 1 epochs
# current #steps=0, #epochs=1
# start training...
# ---------------
# 2026-02-21 19:01:17.934138
# current #epochs=1, #steps=0
# z:\AST-With-TB-Classify\venvast\lib\site-packages\torch\cuda\amp\grad_scaler.py:116: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")
# z:\AST-With-TB-Classify\venvast\lib\site-packages\torch\cuda\amp\autocast_mode.py:118: UserWarning: torch.cuda.amp.autocast only affects CUDA ops, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.autocast only affects CUDA ops, but CUDA is not available.  Disabling.")
# Epoch: [1][10/41]	Per Sample Total Time 1.93286	Per Sample Data Time 0.01728	Per Sample DNN Time 1.91560	Train Loss 0.5245
# Epoch: [1][20/41]	Per Sample Total Time 1.80279	Per Sample Data Time 0.01562	Per Sample DNN Time 1.78718	Train Loss 0.4615
# Epoch: [1][30/41]	Per Sample Total Time 1.54985	Per Sample Data Time 0.01295	Per Sample DNN Time 1.53690	Train Loss 0.4170
# Epoch: [1][40/41]	Per Sample Total Time 1.53816	Per Sample Data Time 0.01203	Per Sample DNN Time 1.52613	Train Loss 0.3819
# start validation
# mAP: 0.929290
# AUC: 0.927976
# Avg Precision: 0.707404
# Avg Recall: 1.000000
# d_prime: 2.066000
# train_loss: 0.381886
# valid_loss: 0.559239
# validation finished
# Epoch-1 lr: 1e-05
# epoch 1 training time: 541.964
# ---------------
# 2026-02-21 19:10:19.903983
# current #epochs=2, #steps=41
# z:\AST-With-TB-Classify\venvast\lib\site-packages\torch\cuda\amp\autocast_mode.py:118: UserWarning: torch.cuda.amp.autocast only affects CUDA ops, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.autocast only affects CUDA ops, but CUDA is not available.  Disabling.")
# Epoch: [2][9/41]	Per Sample Total Time 1.36346	Per Sample Data Time 0.00864	Per Sample DNN Time 1.35482	Train Loss 0.2206
# Epoch: [2][19/41]	Per Sample Total Time 1.39741	Per Sample Data Time 0.00971	Per Sample DNN Time 1.38770	Train Loss 0.2268
# Epoch: [2][29/41]	Per Sample Total Time 1.41988	Per Sample Data Time 0.01009	Per Sample DNN Time 1.40980	Train Loss 0.2232
# Epoch: [2][39/41]	Per Sample Total Time 1.41401	Per Sample Data Time 0.00970	Per Sample DNN Time 1.40432	Train Loss 0.2198
# start validation
# mAP: 0.785635
# AUC: 0.777976
# Avg Precision: 0.543158
# Avg Recall: 1.000000
# d_prime: 1.082405
# train_loss: 0.215953
# valid_loss: 0.603083
# validation finished
# Epoch-2 lr: 1e-05
# epoch 2 training time: 495.397
# ---------------
# 2026-02-21 19:18:35.295288
# current #epochs=3, #steps=82
# z:\AST-With-TB-Classify\venvast\lib\site-packages\torch\cuda\amp\autocast_mode.py:118: UserWarning: torch.cuda.amp.autocast only affects CUDA ops, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.autocast only affects CUDA ops, but CUDA is not available.  Disabling.")
# Epoch: [3][8/41]	Per Sample Total Time 1.34889	Per Sample Data Time 0.00911	Per Sample DNN Time 1.33977	Train Loss 0.1684
# Epoch: [3][18/41]	Per Sample Total Time 1.36081	Per Sample Data Time 0.00906	Per Sample DNN Time 1.35175	Train Loss 0.1529
# Epoch: [3][28/41]	Per Sample Total Time 1.38319	Per Sample Data Time 0.01033	Per Sample DNN Time 1.37286	Train Loss 0.1460
# Epoch: [3][38/41]	Per Sample Total Time 1.37890	Per Sample Data Time 0.00982	Per Sample DNN Time 1.36908	Train Loss 0.1634
# start validation
# mAP: 0.849780
# AUC: 0.844643
# Avg Precision: 0.550270
# Avg Recall: 1.000000
# d_prime: 1.433623
# train_loss: 0.163620
# valid_loss: 0.600347
# validation finished
# Epoch-3 lr: 1e-05
# epoch 3 training time: 484.124
# ---------------
# 2026-02-21 19:26:39.418624
# current #epochs=4, #steps=123
# z:\AST-With-TB-Classify\venvast\lib\site-packages\torch\cuda\amp\autocast_mode.py:118: UserWarning: torch.cuda.amp.autocast only affects CUDA ops, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.autocast only affects CUDA ops, but CUDA is not available.  Disabling.")
# Epoch: [4][7/41]	Per Sample Total Time 1.36763	Per Sample Data Time 0.01020	Per Sample DNN Time 1.35743	Train Loss 0.0853
# Epoch: [4][17/41]	Per Sample Total Time 1.45024	Per Sample Data Time 0.01018	Per Sample DNN Time 1.44006	Train Loss 0.1534
# Epoch: [4][27/41]	Per Sample Total Time 1.43432	Per Sample Data Time 0.01018	Per Sample DNN Time 1.42414	Train Loss 0.1782
# Epoch: [4][37/41]	Per Sample Total Time 1.38868	Per Sample Data Time 0.00947	Per Sample DNN Time 1.37921	Train Loss 0.1590
# start validation
# mAP: 0.927873
# AUC: 0.924702
# Avg Precision: 0.663508
# Avg Recall: 1.000000
# d_prime: 2.032836
# train_loss: 0.150838
# valid_loss: 0.524147
# validation finished
# Epoch-4 lr: 1e-05
# epoch 4 training time: 482.179
# ---------------
# 2026-02-21 19:34:41.598197
# current #epochs=5, #steps=164
# z:\AST-With-TB-Classify\venvast\lib\site-packages\torch\cuda\amp\autocast_mode.py:118: UserWarning: torch.cuda.amp.autocast only affects CUDA ops, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.autocast only affects CUDA ops, but CUDA is not available.  Disabling.")
# Epoch: [5][6/41]	Per Sample Total Time 1.29274	Per Sample Data Time 0.00684	Per Sample DNN Time 1.28590	Train Loss 0.0871
# Epoch: [5][16/41]	Per Sample Total Time 1.43954	Per Sample Data Time 0.01113	Per Sample DNN Time 1.42842	Train Loss 0.0540
# Epoch: [5][26/41]	Per Sample Total Time 1.47077	Per Sample Data Time 0.01070	Per Sample DNN Time 1.46007	Train Loss 0.0647
# Epoch: [5][36/41]	Per Sample Total Time 1.47443	Per Sample Data Time 0.01017	Per Sample DNN Time 1.46426	Train Loss 0.0731
# start validation
# mAP: 0.894259
# AUC: 0.885417
# Avg Precision: 0.631818
# Avg Recall: 1.000000
# d_prime: 1.700603
# train_loss: 0.092983
# valid_loss: 0.552283
# validation finished
# Epoch-5 lr: 8.5e-06
# epoch 5 training time: 519.622
# ---------------
# 2026-02-21 19:43:21.219638
# current #epochs=6, #steps=205
# z:\AST-With-TB-Classify\venvast\lib\site-packages\torch\cuda\amp\autocast_mode.py:118: UserWarning: torch.cuda.amp.autocast only affects CUDA ops, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.autocast only affects CUDA ops, but CUDA is not available.  Disabling.")
# Epoch: [6][5/41]	Per Sample Total Time 1.56071	Per Sample Data Time 0.00870	Per Sample DNN Time 1.55200	Train Loss 0.0915
# Epoch: [6][15/41]	Per Sample Total Time 1.45400	Per Sample Data Time 0.00818	Per Sample DNN Time 1.44582	Train Loss 0.1052
# Epoch: [6][25/41]	Per Sample Total Time 1.42919	Per Sample Data Time 0.00805	Per Sample DNN Time 1.42114	Train Loss 0.0877
# Epoch: [6][35/41]	Per Sample Total Time 1.38196	Per Sample Data Time 0.00784	Per Sample DNN Time 1.37412	Train Loss 0.0821
# start validation
# mAP: 0.853270
# AUC: 0.844643
# Avg Precision: 0.578125
# Avg Recall: 1.000000
# d_prime: 1.433623
# train_loss: 0.104037
# valid_loss: 0.553042
# validation finished
# Epoch-6 lr: 7.2249999999999994e-06
# epoch 6 training time: 479.002
# ---------------
# 2026-02-21 19:51:20.220193
# current #epochs=7, #steps=246
# z:\AST-With-TB-Classify\venvast\lib\site-packages\torch\cuda\amp\autocast_mode.py:118: UserWarning: torch.cuda.amp.autocast only affects CUDA ops, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.autocast only affects CUDA ops, but CUDA is not available.  Disabling.")
# Epoch: [7][4/41]	Per Sample Total Time 1.26880	Per Sample Data Time 0.00709	Per Sample DNN Time 1.26171	Train Loss 0.3215
# Epoch: [7][14/41]	Per Sample Total Time 1.27251	Per Sample Data Time 0.00738	Per Sample DNN Time 1.26513	Train Loss 0.1653
# Epoch: [7][24/41]	Per Sample Total Time 1.27118	Per Sample Data Time 0.00749	Per Sample DNN Time 1.26370	Train Loss 0.1457
# Epoch: [7][34/41]	Per Sample Total Time 1.27214	Per Sample Data Time 0.00747	Per Sample DNN Time 1.26467	Train Loss 0.1560
# start validation
# mAP: 0.909125
# AUC: 0.908333
# Avg Precision: 0.618235
# Avg Recall: 1.000000
# d_prime: 1.881698
# train_loss: 0.141206
# valid_loss: 0.512479
# validation finished
# Epoch-7 lr: 6.141249999999999e-06
# epoch 7 training time: 447.293
# ---------------
# 2026-02-21 19:58:47.514228
# current #epochs=8, #steps=287
# z:\AST-With-TB-Classify\venvast\lib\site-packages\torch\cuda\amp\autocast_mode.py:118: UserWarning: torch.cuda.amp.autocast only affects CUDA ops, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.autocast only affects CUDA ops, but CUDA is not available.  Disabling.")
# Epoch: [8][3/41]	Per Sample Total Time 1.26919	Per Sample Data Time 0.00631	Per Sample DNN Time 1.26288	Train Loss 0.1215
# Epoch: [8][13/41]	Per Sample Total Time 1.25405	Per Sample Data Time 0.00686	Per Sample DNN Time 1.24719	Train Loss 0.1868
# Epoch: [8][23/41]	Per Sample Total Time 1.25076	Per Sample Data Time 0.00712	Per Sample DNN Time 1.24365	Train Loss 0.1231
# Epoch: [8][33/41]	Per Sample Total Time 1.25332	Per Sample Data Time 0.00684	Per Sample DNN Time 1.24648	Train Loss 0.1148
# start validation
# mAP: 0.879935
# AUC: 0.872917
# Avg Precision: 0.563433
# Avg Recall: 1.000000
# d_prime: 1.612610
# train_loss: 0.119385
# valid_loss: 0.526103
# validation finished
# Epoch-8 lr: 5.220062499999999e-06
# epoch 8 training time: 442.288
# ---------------
# 2026-02-21 20:06:09.801982
# current #epochs=9, #steps=328
# z:\AST-With-TB-Classify\venvast\lib\site-packages\torch\cuda\amp\autocast_mode.py:118: UserWarning: torch.cuda.amp.autocast only affects CUDA ops, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.autocast only affects CUDA ops, but CUDA is not available.  Disabling.")
# Epoch: [9][2/41]	Per Sample Total Time 1.27650	Per Sample Data Time 0.00754	Per Sample DNN Time 1.26896	Train Loss 0.0299
# Epoch: [9][12/41]	Per Sample Total Time 1.26632	Per Sample Data Time 0.00698	Per Sample DNN Time 1.25934	Train Loss 0.1020
# Epoch: [9][22/41]	Per Sample Total Time 1.26239	Per Sample Data Time 0.00711	Per Sample DNN Time 1.25529	Train Loss 0.0878
# Epoch: [9][32/41]	Per Sample Total Time 1.25852	Per Sample Data Time 0.00710	Per Sample DNN Time 1.25142	Train Loss 0.0848
# start validation
# mAP: 0.935057
# AUC: 0.933631
# Avg Precision: 0.689266
# Avg Recall: 1.000000
# d_prime: 2.126117
# train_loss: 0.075628
# valid_loss: 0.492178
# validation finished
# Epoch-9 lr: 4.4370531249999995e-06
# epoch 9 training time: 444.476
# ---------------
# 2026-02-21 20:13:34.277660
# current #epochs=10, #steps=369
# z:\AST-With-TB-Classify\venvast\lib\site-packages\torch\cuda\amp\autocast_mode.py:118: UserWarning: torch.cuda.amp.autocast only affects CUDA ops, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.autocast only affects CUDA ops, but CUDA is not available.  Disabling.")
# Epoch: [10][1/41]	Per Sample Total Time 1.27394	Per Sample Data Time 0.00663	Per Sample DNN Time 1.26731	Train Loss 0.0211
# Epoch: [10][11/41]	Per Sample Total Time 1.25565	Per Sample Data Time 0.00712	Per Sample DNN Time 1.24853	Train Loss 0.0345
# Epoch: [10][21/41]	Per Sample Total Time 1.26218	Per Sample Data Time 0.00710	Per Sample DNN Time 1.25508	Train Loss 0.0422
# Epoch: [10][31/41]	Per Sample Total Time 1.25829	Per Sample Data Time 0.00692	Per Sample DNN Time 1.25137	Train Loss 0.0561
# start validation
# mAP: 0.933356
# AUC: 0.933333
# Avg Precision: 0.713075
# Avg Recall: 1.000000
# d_prime: 2.122856
# train_loss: 0.051920
# valid_loss: 0.489863
# validation finished
# Epoch-10 lr: 3.7714951562499997e-06
# epoch 10 training time: 442.433
# ---------------
# 2026-02-21 20:20:56.710903
# current #epochs=11, #steps=410
# z:\AST-With-TB-Classify\venvast\lib\site-packages\torch\cuda\amp\autocast_mode.py:118: UserWarning: torch.cuda.amp.autocast only affects CUDA ops, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.autocast only affects CUDA ops, but CUDA is not available.  Disabling.")
# Epoch: [11][0/41]	Per Sample Total Time 1.26865	Per Sample Data Time 0.00644	Per Sample DNN Time 1.26221	Train Loss 0.0095
# Epoch: [11][10/41]	Per Sample Total Time 1.26188	Per Sample Data Time 0.00722	Per Sample DNN Time 1.25466	Train Loss 0.0630
# Epoch: [11][20/41]	Per Sample Total Time 1.28394	Per Sample Data Time 0.01198	Per Sample DNN Time 1.27197	Train Loss 0.0581
# Epoch: [11][30/41]	Per Sample Total Time 1.27996	Per Sample Data Time 0.01046	Per Sample DNN Time 1.26951	Train Loss 0.0608
# Epoch: [11][40/41]	Per Sample Total Time 1.27821	Per Sample Data Time 0.00966	Per Sample DNN Time 1.26856	Train Loss 0.0611
# start validation
# mAP: 0.892591
# AUC: 0.888393
# Avg Precision: 0.616516
# Avg Recall: 1.000000
# d_prime: 1.722548
# train_loss: 0.061065
# valid_loss: 0.533149
# validation finished
# Epoch-11 lr: 3.2057708828124997e-06
# epoch 11 training time: 449.332
# ---------------
# 2026-02-21 20:28:26.042404
# current #epochs=12, #steps=451
# z:\AST-With-TB-Classify\venvast\lib\site-packages\torch\cuda\amp\autocast_mode.py:118: UserWarning: torch.cuda.amp.autocast only affects CUDA ops, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.autocast only affects CUDA ops, but CUDA is not available.  Disabling.")
# Epoch: [12][9/41]	Per Sample Total Time 1.27226	Per Sample Data Time 0.00670	Per Sample DNN Time 1.26556	Train Loss 0.1364
# Epoch: [12][19/41]	Per Sample Total Time 1.26417	Per Sample Data Time 0.00711	Per Sample DNN Time 1.25706	Train Loss 0.0893
# Epoch: [12][29/41]	Per Sample Total Time 1.26098	Per Sample Data Time 0.00707	Per Sample DNN Time 1.25391	Train Loss 0.0966
# Epoch: [12][39/41]	Per Sample Total Time 1.26136	Per Sample Data Time 0.00745	Per Sample DNN Time 1.25391	Train Loss 0.0916
# start validation
# mAP: 0.898784
# AUC: 0.895536
# Avg Precision: 0.602855
# Avg Recall: 1.000000
# d_prime: 1.776983
# train_loss: 0.089965
# valid_loss: 0.525531
# validation finished
# Epoch-12 lr: 2.7249052503906246e-06
# epoch 12 training time: 445.537
# ---------------
# 2026-02-21 20:35:51.579334
# current #epochs=13, #steps=492
# z:\AST-With-TB-Classify\venvast\lib\site-packages\torch\cuda\amp\autocast_mode.py:118: UserWarning: torch.cuda.amp.autocast only affects CUDA ops, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.autocast only affects CUDA ops, but CUDA is not available.  Disabling.")
# Epoch: [13][8/41]	Per Sample Total Time 1.25948	Per Sample Data Time 0.00703	Per Sample DNN Time 1.25245	Train Loss 0.0393
# Epoch: [13][18/41]	Per Sample Total Time 1.26202	Per Sample Data Time 0.00709	Per Sample DNN Time 1.25493	Train Loss 0.0751
# Epoch: [13][28/41]	Per Sample Total Time 1.26075	Per Sample Data Time 0.00747	Per Sample DNN Time 1.25327	Train Loss 0.0548
# Epoch: [13][38/41]	Per Sample Total Time 1.26137	Per Sample Data Time 0.00726	Per Sample DNN Time 1.25410	Train Loss 0.0553
# start validation
# mAP: 0.890383
# AUC: 0.885714
# Avg Precision: 0.575490
# Avg Recall: 1.000000
# d_prime: 1.702780
# train_loss: 0.070267
# valid_loss: 0.520067
# validation finished
# Epoch-13 lr: 2.316169462832031e-06
# epoch 13 training time: 444.059
# ---------------
# 2026-02-21 20:43:15.637790
# current #epochs=14, #steps=533
# z:\AST-With-TB-Classify\venvast\lib\site-packages\torch\cuda\amp\autocast_mode.py:118: UserWarning: torch.cuda.amp.autocast only affects CUDA ops, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.autocast only affects CUDA ops, but CUDA is not available.  Disabling.")
# Epoch: [14][7/41]	Per Sample Total Time 1.28021	Per Sample Data Time 0.00756	Per Sample DNN Time 1.27265	Train Loss 0.1124
# Epoch: [14][17/41]	Per Sample Total Time 1.29454	Per Sample Data Time 0.00825	Per Sample DNN Time 1.28629	Train Loss 0.0951
# Epoch: [14][27/41]	Per Sample Total Time 1.42542	Per Sample Data Time 0.00901	Per Sample DNN Time 1.41642	Train Loss 0.0949
# Epoch: [14][37/41]	Per Sample Total Time 1.48316	Per Sample Data Time 0.00973	Per Sample DNN Time 1.47343	Train Loss 0.0836
# start validation
# mAP: 0.890276
# AUC: 0.887500
# Avg Precision: 0.586038
# Avg Recall: 1.000000
# d_prime: 1.715921
# train_loss: 0.079498
# valid_loss: 0.522301
# validation finished
# Epoch-14 lr: 1.9687440434072264e-06
# epoch 14 training time: 519.745
# ---------------
# 2026-02-21 20:51:55.383144
# current #epochs=15, #steps=574
# z:\AST-With-TB-Classify\venvast\lib\site-packages\torch\cuda\amp\autocast_mode.py:118: UserWarning: torch.cuda.amp.autocast only affects CUDA ops, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.autocast only affects CUDA ops, but CUDA is not available.  Disabling.")
# Epoch: [15][6/41]	Per Sample Total Time 1.31557	Per Sample Data Time 0.00838	Per Sample DNN Time 1.30719	Train Loss 0.0778
# Epoch: [15][16/41]	Per Sample Total Time 1.34361	Per Sample Data Time 0.00832	Per Sample DNN Time 1.33529	Train Loss 0.0894
# Epoch: [15][26/41]	Per Sample Total Time 1.34512	Per Sample Data Time 0.00845	Per Sample DNN Time 1.33667	Train Loss 0.0759
# Epoch: [15][36/41]	Per Sample Total Time 1.34285	Per Sample Data Time 0.00827	Per Sample DNN Time 1.33459	Train Loss 0.0607
# start validation
# mAP: 0.875825
# AUC: 0.873810
# Avg Precision: 0.582126
# Avg Recall: 1.000000
# d_prime: 1.618688
# train_loss: 0.057731
# valid_loss: 0.534442
# validation finished
# Epoch-15 lr: 1.6734324368961425e-06
# epoch 15 training time: 471.537
# ---------------
# 2026-02-21 20:59:46.919467
# current #epochs=16, #steps=615
# z:\AST-With-TB-Classify\venvast\lib\site-packages\torch\cuda\amp\autocast_mode.py:118: UserWarning: torch.cuda.amp.autocast only affects CUDA ops, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.autocast only affects CUDA ops, but CUDA is not available.  Disabling.")
# Epoch: [16][5/41]	Per Sample Total Time 1.35213	Per Sample Data Time 0.00786	Per Sample DNN Time 1.34426	Train Loss 0.0052
# Epoch: [16][15/41]	Per Sample Total Time 1.33071	Per Sample Data Time 0.00772	Per Sample DNN Time 1.32299	Train Loss 0.0882
# Epoch: [16][25/41]	Per Sample Total Time 1.35088	Per Sample Data Time 0.00891	Per Sample DNN Time 1.34197	Train Loss 0.0720
# Epoch: [16][35/41]	Per Sample Total Time 1.37570	Per Sample Data Time 0.00898	Per Sample DNN Time 1.36672	Train Loss 0.0678
# start validation
# mAP: 0.870862
# AUC: 0.869643
# Avg Precision: 0.567506
# Avg Recall: 1.000000
# d_prime: 1.590572
# train_loss: 0.063046
# valid_loss: 0.530254
# validation finished
# Epoch-16 lr: 1.422417571361721e-06
# epoch 16 training time: 489.673
# ---------------
# 2026-02-21 21:07:56.592997
# current #epochs=17, #steps=656
# z:\AST-With-TB-Classify\venvast\lib\site-packages\torch\cuda\amp\autocast_mode.py:118: UserWarning: torch.cuda.amp.autocast only affects CUDA ops, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.autocast only affects CUDA ops, but CUDA is not available.  Disabling.")
# Epoch: [17][4/41]	Per Sample Total Time 1.47971	Per Sample Data Time 0.01364	Per Sample DNN Time 1.46607	Train Loss 0.0272
# Epoch: [17][14/41]	Per Sample Total Time 1.46741	Per Sample Data Time 0.01023	Per Sample DNN Time 1.45718	Train Loss 0.0976
# Epoch: [17][24/41]	Per Sample Total Time 1.46418	Per Sample Data Time 0.01014	Per Sample DNN Time 1.45404	Train Loss 0.0844
# Epoch: [17][34/41]	Per Sample Total Time 1.44470	Per Sample Data Time 0.00981	Per Sample DNN Time 1.43490	Train Loss 0.0686
# start validation
# mAP: 0.880621
# AUC: 0.880060
# Avg Precision: 0.582126
# Avg Recall: 1.000000
# d_prime: 1.662103
# train_loss: 0.064603
# valid_loss: 0.527060
# validation finished
# Epoch-17 lr: 1.2090549356574628e-06
# epoch 17 training time: 507.902
# ---------------
# 2026-02-21 21:16:24.495924
# current #epochs=18, #steps=697
# z:\AST-With-TB-Classify\venvast\lib\site-packages\torch\cuda\amp\autocast_mode.py:118: UserWarning: torch.cuda.amp.autocast only affects CUDA ops, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.autocast only affects CUDA ops, but CUDA is not available.  Disabling.")
# Epoch: [18][3/41]	Per Sample Total Time 1.32698	Per Sample Data Time 0.00717	Per Sample DNN Time 1.31981	Train Loss 0.0482
# Epoch: [18][13/41]	Per Sample Total Time 1.31527	Per Sample Data Time 0.00744	Per Sample DNN Time 1.30783	Train Loss 0.0671
# Epoch: [18][23/41]	Per Sample Total Time 1.32568	Per Sample Data Time 0.00746	Per Sample DNN Time 1.31822	Train Loss 0.0648
# Epoch: [18][33/41]	Per Sample Total Time 1.31919	Per Sample Data Time 0.00743	Per Sample DNN Time 1.31176	Train Loss 0.0505
# start validation
# mAP: 0.889638
# AUC: 0.886905
# Avg Precision: 0.595123
# Avg Recall: 1.000000
# d_prime: 1.711524
# train_loss: 0.064975
# valid_loss: 0.540038
# validation finished
# Epoch-18 lr: 1.0276966953088434e-06
# epoch 18 training time: 474.386
# ---------------
# 2026-02-21 21:24:18.879869
# current #epochs=19, #steps=738
# z:\AST-With-TB-Classify\venvast\lib\site-packages\torch\cuda\amp\autocast_mode.py:118: UserWarning: torch.cuda.amp.autocast only affects CUDA ops, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.autocast only affects CUDA ops, but CUDA is not available.  Disabling.")
# Epoch: [19][2/41]	Per Sample Total Time 1.43107	Per Sample Data Time 0.01302	Per Sample DNN Time 1.41804	Train Loss 0.2415
# Epoch: [19][12/41]	Per Sample Total Time 1.57214	Per Sample Data Time 0.01668	Per Sample DNN Time 1.55546	Train Loss 0.1184
# Epoch: [19][22/41]	Per Sample Total Time 1.49173	Per Sample Data Time 0.01304	Per Sample DNN Time 1.47869	Train Loss 0.0965
# Epoch: [19][32/41]	Per Sample Total Time 1.53246	Per Sample Data Time 0.01249	Per Sample DNN Time 1.51997	Train Loss 0.0933
# start validation
# mAP: 0.894330
# AUC: 0.891369
# Avg Precision: 0.608037
# Avg Recall: 1.000000
# d_prime: 1.744916
# train_loss: 0.095212
# valid_loss: 0.515124
# validation finished
# Epoch-19 lr: 8.735421910125168e-07
# epoch 19 training time: 538.462
# ---------------
# 2026-02-21 21:33:17.343100
# current #epochs=20, #steps=779
# z:\AST-With-TB-Classify\venvast\lib\site-packages\torch\cuda\amp\autocast_mode.py:118: UserWarning: torch.cuda.amp.autocast only affects CUDA ops, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.autocast only affects CUDA ops, but CUDA is not available.  Disabling.")
# Epoch: [20][1/41]	Per Sample Total Time 1.49098	Per Sample Data Time 0.03094	Per Sample DNN Time 1.46003	Train Loss 0.0056
# Epoch: [20][11/41]	Per Sample Total Time 1.54851	Per Sample Data Time 0.01584	Per Sample DNN Time 1.53267	Train Loss 0.0531
# Epoch: [20][21/41]	Per Sample Total Time 1.60704	Per Sample Data Time 0.01626	Per Sample DNN Time 1.59078	Train Loss 0.0473
# Epoch: [20][31/41]	Per Sample Total Time 1.55898	Per Sample Data Time 0.01431	Per Sample DNN Time 1.54466	Train Loss 0.0439
# start validation
# mAP: 0.896764
# AUC: 0.894643
# Avg Precision: 0.608037
# Avg Recall: 1.000000
# d_prime: 1.770035
# train_loss: 0.045379
# valid_loss: 0.515885
# validation finished
# Epoch-20 lr: 7.425108623606393e-07
# epoch 20 training time: 552.000
# ---------------Training Finished---------------
# weighted averaged model results
# mAP: 0.893968
# AUC: 0.891667
# Avg Precision: 0.611940
# Avg Recall: 1.000000
# d_prime: 1.747176
# train_loss: 0.000000
# valid_loss: 0.515885
#
# Training complete. Model checkpoints saved to: ./exp/tb_ast_p_augmented

# %% [markdown]
# ### Load Best Model & Run Inference on Test Set
#
# Best Epoch ถูกเลือกจากค่า **mAUC สูงสุด** ใน `result.csv`:
#
# - คอลัมน์ Index 0 = `acc`
# - **คอลัมน์ Index 1 = `mAUC`** ← ใช้เลือก Best Epoch
# - คอลัมน์ Index 2 = `average_precision`
#
# Raw Logits จากโมเดล → **Softmax** → ค่าความน่าจะเป็น PTB (Class 1)

# %%
def load_best_model_by_mauc(exp_dir: str, n_class: int) -> tuple:
    """
    โหลด Best Model โดยเลือก Epoch ที่ให้ค่า mAUC สูงที่สุดจาก result.csv

    Columns ใน result.csv (0-indexed):
      0: acc | 1: mAUC | 2: avg_precision | 3: avg_recall |
      4: d_prime | 5: train_loss | 6: valid_loss | 7: cum_acc |
      8: cum_mAUC | 9: lr

    Returns
    -------
    model      : โมเดลที่โหลดน้ำหนักแล้ว (nn.DataParallel, eval mode)
    best_epoch : หมายเลข Epoch ที่ดีที่สุด (1-indexed)
    best_mauc  : ค่า mAUC สูงสุด
    """
    result_path = os.path.join(exp_dir, "result.csv")
    if not os.path.exists(result_path):
        raise FileNotFoundError(f"ไม่พบ result.csv ที่ {result_path}")

    result = np.loadtxt(result_path, delimiter=",")
    if result.ndim == 1:
        result = result[np.newaxis, :]  # กรณีมีแค่ 1 epoch

    # ── Column Index 1 = mAUC ────────────────────────────────────────────────
    mauc_col   = result[:, 1]
    best_idx   = int(np.argmax(mauc_col))    # 0-indexed row
    best_epoch = best_idx + 1                # 1-indexed epoch number
    best_mauc  = float(mauc_col[best_idx])

    print(f"result.csv  : {result.shape[0]} epochs found")
    print(f"Best Epoch  : {best_epoch}  (mAUC = {best_mauc:.6f})")

    # ── โหลดโมเดล ─────────────────────────────────────────────────────────────
    model_path = os.path.join(exp_dir, "models", f"audio_model.{best_epoch}.pth")

    # ลอง WA model ถ้าไม่พบ per-epoch checkpoint
    if not os.path.exists(model_path):
        wa_path = os.path.join(exp_dir, "models", "audio_model_wa.pth")
        if os.path.exists(wa_path):
            print(f"[INFO] ไม่พบ audio_model.{best_epoch}.pth → ใช้ audio_model_wa.pth แทน")
            model_path = wa_path
        else:
            raise FileNotFoundError(f"ไม่พบ checkpoint: {model_path}")

    print(f"Loading     : {model_path}")

    # สร้างโมเดลใหม่ (ไม่โหลด Pretrained ซ้ำ)
    model = ASTModel(
        label_dim        = n_class,
        fstride          = 10,
        tstride          = 10,
        input_fdim       = 128,
        input_tdim       = 100,
        imagenet_pretrain = False,
        audioset_pretrain = False,
        model_size       = "base384",
        verbose          = False,
    )
    model = torch.nn.DataParallel(model)
    state_dict = torch.load(model_path, map_location=device)
    model.load_state_dict(state_dict)
    model = model.to(device)
    model.eval()

    return model, best_epoch, best_mauc


def run_inference_softmax(model, data_json: str, audio_conf: dict) -> tuple:
    """
    รันโมเดลบน Dataset ที่กำหนด พร้อมแปลง Raw Logits → Softmax Probabilities

    Returns
    -------
    all_probs  : np.ndarray shape (N, n_class) — Softmax probabilities
    all_labels : np.ndarray shape (N, n_class) — One-hot ground truth
    ptb_probs  : np.ndarray shape (N,)          — P(PTB=1) per sample
    true_labels: np.ndarray shape (N,)          — Binary int labels
    """
    test_loader = torch.utils.data.DataLoader(
        dataloader.AudiosetDataset(
            data_json,
            label_csv  = "class_labels_indices.csv",
            audio_conf = audio_conf,
        ),
        batch_size = 16,
        shuffle    = False,
        num_workers= 0,
        pin_memory = True,
    )

    all_probs_list  = []
    all_labels_list = []

    with torch.no_grad():
        for audio_input, labels in test_loader:
            audio_input = audio_input.to(device)               # (B, T, F)
            logits      = model(audio_input)                   # (B, 2) — Raw Logits
            probs       = F.softmax(logits, dim=-1)            # (B, 2) — Softmax
            all_probs_list .append(probs.cpu().numpy())
            all_labels_list.append(labels.numpy())

    all_probs  = np.concatenate(all_probs_list,  axis=0)   # (N, 2)
    all_labels = np.concatenate(all_labels_list, axis=0)   # (N, 2)

    # PTB = Class Index 1
    ptb_probs   = all_probs[:, 1]                           # P(PTB)
    true_labels = np.argmax(all_labels, axis=1).astype(int) # 0 or 1

    return all_probs, all_labels, ptb_probs, true_labels


# ── Execute ───────────────────────────────────────────────────────────────────
best_model, BEST_EPOCH, BEST_MAUC = load_best_model_by_mauc(EXP_DIR, N_CLASS)

print(f"\nRunning inference on TEST set ({JSON_PATHS['TEST']}) ...")
ALL_PROBS, ALL_LABELS, PTB_PROBS, TRUE_LABELS = run_inference_softmax(
    best_model, JSON_PATHS["TEST"], EVAL_AUDIO_CONF
)

print(f"\nTest samples     : {len(TRUE_LABELS)}")
print(f"PTB  (label=1)   : {int(TRUE_LABELS.sum())}")
print(f"Non-PTB (label=0): {int((TRUE_LABELS == 0).sum())}")
print(f"\nProbability range: [{PTB_PROBS.min():.4f}, {PTB_PROBS.max():.4f}]")
# Out:
# result.csv  : 20 epochs found
# Best Epoch  : 9  (mAUC = 0.933631)
# Loading     : ./exp/tb_ast_p_augmented\models\audio_model.9.pth
#
# Running inference on TEST set (.\test_data.json) ...
# ---------------the evaluation dataloader---------------
# now using following mask: 0 freq, 0 time
# now using mix-up with rate 0.000000
# now process audioset
# use dataset mean -4.527 and std 5.118 to normalize the input.
# number of classes is 2
#
# Test samples     : 104
# PTB  (label=1)   : 31
# Non-PTB (label=0): 73
#
# Probability range: [0.0003, 0.9894]

# %% [markdown]
# ### Performance Evaluation & Visualization
#
# Metrics ที่คำนวณ:
#
# | Metric                | Description                                             |
# | --------------------- | ------------------------------------------------------- |
# | **AUROC**             | Area Under ROC Curve — ความสามารถในการแยกแยะทั้งสองคลาส |
# | **AUPRC**             | Area Under Precision-Recall Curve                       |
# | **Sensitivity (TPR)** | TP / (TP + FN) — ที่ Threshold = 0.5                    |
# | **Specificity (TNR)** | TN / (TN + FP) — ที่ Threshold = 0.5                    |
#
# กราฟ: **ROC Curve** + **Confusion Matrix** ใน layout 1 row × 2 columns

# %%
def evaluate_and_visualize(
    ptb_probs  : np.ndarray,
    true_labels: np.ndarray,
    threshold  = 'auto',          # เปลี่ยน Default เป็น 'auto'
    best_epoch : int   = 0,
    best_mauc  : float = 0.0,
    save_path  : str   = None,
):
    """
    คำนวณ AUROC / AUPRC / Sensitivity / Specificity
    และวาดกราฟ ROC Curve + Confusion Matrix พร้อมหา Optimal Threshold ด้วย Youden's J
    """
    CLASS_NAMES = ["Non-PTB (0)", "PTB (1)"]

    # ── 1. คำนวณ ROC และหา Optimal Threshold ────────────────────────────────────
    fpr, tpr, thresholds_roc = roc_curve(true_labels, ptb_probs)
    auroc = roc_auc_score(true_labels, ptb_probs)
    auprc = average_precision_score(true_labels, ptb_probs)

    # หากตั้งเป็น 'auto' ให้ใช้ Youden's J Index หาค่าที่ดีที่สุด
    if threshold == 'auto':
        j_scores = tpr - fpr
        optimal_idx = np.argmax(j_scores)
        optimal_threshold = thresholds_roc[optimal_idx]
        print(f"[INFO] Auto-optimized threshold using Youden's J: {optimal_threshold:.4f}")
        threshold = optimal_threshold
    else:
        threshold = float(threshold)
    # ── 2. คำนวณ Metrics ที่ Threshold ที่เลือก ──────────────────────────────────
    pred_labels = (ptb_probs >= threshold).astype(int)
    cm = confusion_matrix(true_labels, pred_labels)

    tn, fp, fn, tp = cm.ravel()
    sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0.0  
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0.0  
    accuracy    = (tp + tn) / len(true_labels)

    print("=" * 55)
    print("          AST-P PERFORMANCE SUMMARY")
    print("=" * 55)
    print(f"  Threshold     : {threshold:.4f}")
    print("-" * 55)
    print(f"  AUROC         : {auroc:.4f}")
    print(f"  AUPRC         : {auprc:.4f}")
    print(f"  Accuracy      : {accuracy:.4f}")
    print(f"  Sensitivity   : {sensitivity:.4f}  (TPR / Recall)")
    print(f"  Specificity   : {specificity:.4f}  (TNR)")
    print("-" * 55)
    print(f"  TP={tp}, TN={tn}, FP={fp}, FN={fn}")
    print("=" * 55)

    # ── 3. Plot กราฟ ────────────────────────────────────────────────────────
    fig, axes = plt.subplots(1, 2, figsize=(13, 5))
    fig.suptitle(
        f"Spectrogram - AST-P - Augmented\n",
        fontsize=13, fontweight="bold"
    )

    # Left: ROC Curve
    ax_roc = axes[0]
    ax_roc.plot(fpr, tpr, color="#2196F3", lw=2, label=f"ROC Curve (AUROC = {auroc:.4f})")
    ax_roc.plot([0, 1], [0, 1], color="gray", lw=1.2, linestyle="--", label="Random")

    # วาดจุด Operating Point 
    op_fpr = fp / (fp + tn) if (fp + tn) > 0 else 0.0
    op_tpr = sensitivity
    ax_roc.scatter(
        op_fpr, op_tpr,
        s=80, color="#E53935", zorder=5,
        label=f"Opt. Threshold={threshold:.3f}  (TPR={op_tpr:.3f}, FPR={op_fpr:.3f})"
    )

    ax_roc.set_xlabel("False Positive Rate (FPR)", fontsize=11)
    ax_roc.set_ylabel("True Positive Rate (TPR)", fontsize=11)
    ax_roc.set_title("ROC Curve with Youden's J Optimization", fontsize=12)
    ax_roc.legend(loc="lower right", fontsize=9)
    ax_roc.grid(True, alpha=0.35)

    # Right: Confusion Matrix
    ax_cm = axes[1]
    import seaborn as sns
    sns.heatmap(
        cm, annot=True, fmt="d", cmap="Blues",
        xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES, ax=ax_cm,
        linewidths=0.5, linecolor="white", annot_kws={"size": 13, "weight": "bold"},
    )
    ax_cm.set_xlabel("Predicted Label", fontsize=11)
    ax_cm.set_ylabel("True Label",      fontsize=11)
    ax_cm.set_title(
        f"Confusion Matrix (Threshold = {threshold:.3f})\n"
        f"Sens = {sensitivity:.4f} | Spec = {specificity:.4f}",
        fontsize=11
    )

    plt.tight_layout()
    if save_path:
        plt.savefig(save_path, dpi=150, bbox_inches="tight")
    plt.show()

    return {
        "auroc": auroc, "auprc": auprc, "accuracy": accuracy,
        "sensitivity": sensitivity, "specificity": specificity,
        "optimal_threshold": threshold,
        "tp": tp, "tn": tn, "fp": fp, "fn": fn,
    }

# ── Execute ───────────────────────────────────────────────────────────────────
# วิธีเรียกใช้ (ปล่อย threshold ให้เป็น 'auto')
METRICS = evaluate_and_visualize(
    ptb_probs   = PTB_PROBS,
    true_labels = TRUE_LABELS,
    threshold   = 'auto',   # <--- ให้ฟังก์ชันคำนวณให้
    best_epoch  = BEST_EPOCH,
    best_mauc   = BEST_MAUC,
    save_path   = f"{EXP_DIR}/plots/roc_cm_optimized.png",
)
# Out:
# [INFO] Auto-optimized threshold using Youden's J: 0.0702
# =======================================================
#           AST-P PERFORMANCE SUMMARY
# =======================================================
#   Threshold     : 0.0702
# -------------------------------------------------------
#   AUROC         : 0.6796
#   AUPRC         : 0.4629
#   Accuracy      : 0.5769
#   Sensitivity   : 0.9677  (TPR / Recall)
#   Specificity   : 0.4110  (TNR)
# -------------------------------------------------------
#   TP=30, TN=30, FP=43, FN=1
# =======================================================

# %% [markdown]
# ---
#
# ## References
#
# ### AST Model
#
# > **Gong, Y., Chung, Y.-A., & Glass, J. (2021).**
# > *AST: Audio Spectrogram Transformer.*
# > Interspeech 2021. [https://arxiv.org/abs/2104.01778](https://arxiv.org/abs/2104.01778)
#
# ### Normalization Statistics (AudioSet)
#
# | Parameter | Value | Source |
# |-----------|-------|--------|
# | **Mean** | −4.2677393 | Computed from full AudioSet (~2M clips) — reported in AST paper |
# | **Std**  |  4.5689974 | Computed from full AudioSet (~2M clips) — reported in AST paper |
#
# > ค่าเหล่านี้ใช้เพื่อ Normalize Log-Mel Filterbank Features ก่อนป้อนเข้าโมเดล:
# > `normalized = (fbank − mean) / (std × 2)`
# > (ดู `src/dataloader.py`, Line ~87)
#
# ### SpecAugment
#
# > **Park, D. S., et al. (2019).**
# > *SpecAugment: A Simple Data Augmentation Method for Automatic Speech Recognition.*
# > Interspeech 2019. [https://arxiv.org/abs/1904.08779](https://arxiv.org/abs/1904.08779)
#
# ### MixUp
#
# > **Zhang, H., et al. (2018).**
# > *Mixup: Beyond Empirical Risk Minimization.*
# > ICLR 2018. [https://arxiv.org/abs/1710.09412](https://arxiv.org/abs/1710.09412)
#
# ### Vision Transformer (ViT) — Backbone ของ AST
#
# > **Dosovitskiy, A., et al. (2020).**
# > *An Image is Worth 16×16 Words: Transformers for Image Recognition at Scale.*
# > ICLR 2021. [https://arxiv.org/abs/2010.11929](https://arxiv.org/abs/2010.11929)
#
# ### ImageNet Pretrained Weights
#
# > AST-P ใช้ Weights จาก DeiT ที่ Pre-train บน ImageNet (384×384)
# > ผ่าน `timm` library, version **0.4.5** (`timm.create_model("deit_base_distilled_patch16_384")`)
#
# ---
#
# _Notebook นี้พัฒนาสำหรับงาน TB Cough Detection โดยใช้สถาปัตยกรรม AST-P_
